# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from citipy import citipy
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get the API key
weather_api_key = os.getenv("weather_api_key")

# Build the URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes (all of the world)
lat_range = (-90,90)
lng_range = (-180,180)

# %% [markdown]
# Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs  = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1200)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1200)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 492

# %% [markdown]
# Perform API Calls
#
#     Perform a weather check on each city using a series of successive API calls.
#     Include a print log of each city as it's being processed (with the city number and city name).

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for x, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (x % 50 == 0 and x >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la huacana
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | mapastepec
# Processing Record 5 of Set 1 | gaalkacyo
# Processing Record 6 of Set 1 | anadyr
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | rodolfo sanchez taboada
# Processing Record 9 of Set 1 | los llanos de aridane
# Processing Record 10 of Set 1 | gadzhiyevo
# Processing Record 11 of Set 1 | castelli
# Processing Record 12 of Set 1 | olonkinbyen
# Processing Record 13 of Set 1 | bilibino
# Processing Record 14 of Set 1 | kalispell
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | vorgashor
# Processing Record 18 of Set 1 | inverloch
# Processing Record 19 of Set 1 | eenhana
# Processing Record 20 of Set 1 | aasiaat
# Processing Record 21 of Set 1 | papatowai
# Processing Record 22 of Set 1 | holualoa
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | edinburgh of the seven seas
# Processing Record 25 of Set 1 | spirit lake
# Processing Record 26 of Set 1 | tolanaro
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | thunder bay
# Processing Record 29 of Set 1 | mutsu
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | apartado
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | orchard homes
# Processing Record 34 of Set 1 | darhan
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | newman
# Processing Record 37 of Set 1 | kirakira
# Processing Record 38 of Set 1 | nar'yan-mar
# Processing Record 39 of Set 1 | lata
# Processing Record 40 of Set 1 | yanam
# Processing Record 41 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 42 of Set 1 | juneau
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | yuxi
# Processing Record 45 of Set 1 | natal
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | aswan
# Processing Record 48 of Set 1 | puerto natales
# Processing Record 49 of Set 1 | udachny
# Processing Record 50 of Set 1 | blackmans bay
# Processing Record 0 of Set 2 | yellowknife
# Processing Record 1 of Set 2 | isafjordur
# Processing Record 2 of Set 2 | ravar
# Processing Record 3 of Set 2 | kapsowar
# City not found. Skipping...
# Processing Record 4 of Set 2 | campo formoso
# Processing Record 5 of Set 2 | remire-montjoly
# Processing Record 6 of Set 2 | labrador city
# Processing Record 7 of Set 2 | ust'-barguzin
# Processing Record 8 of Set 2 | wynyard
# Processing Record 9 of Set 2 | tazovsky
# Processing Record 10 of Set 2 | filadelfia
# Processing Record 11 of Set 2 | talnakh
# Processing Record 12 of Set 2 | ginir
# Processing Record 13 of Set 2 | gazojak
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | chonchi
# Processing Record 16 of Set 2 | al jawf
# Processing Record 17 of Set 2 | mao
# Processing Record 18 of Set 2 | totness
# Processing Record 19 of Set 2 | la ronge
# Processing Record 20 of Set 2 | alotau
# Processing Record 21 of Set 2 | badger
# Processing Record 22 of Set 2 | vila velha
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | stanley
# Processing Record 26 of Set 2 | jurbarkas
# Processing Record 27 of Set 2 | tralee
# Processing Record 28 of Set 2 | siyabuswa
# Processing Record 29 of Set 2 | kerikeri
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | rongelap
# Processing Record 34 of Set 2 | altay
# Processing Record 35 of Set 2 | invercargill
# Processing Record 36 of Set 2 | sandwip
# Processing Record 37 of Set 2 | harstad
# Processing Record 38 of Set 2 | mount pearl
# Processing Record 39 of Set 2 | berazategui
# Processing Record 40 of Set 2 | lupiro
# Processing Record 41 of Set 2 | newnham
# Processing Record 42 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 2 | waitangi
# Processing Record 44 of Set 2 | valparaiso
# Processing Record 45 of Set 2 | whitehorse
# Processing Record 46 of Set 2 | ust'-ilimsk
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | barbacoas
# Processing Record 49 of Set 2 | barreirinhas
# Processing Record 0 of Set 3 | kijang
# Processing Record 1 of Set 3 | karratha
# Processing Record 2 of Set 3 | lincoln city
# Processing Record 3 of Set 3 | tual
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | west island
# Processing Record 7 of Set 3 | palikir - national government center
# Processing Record 8 of Set 3 | caibarien
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | suva
# Processing Record 11 of Set 3 | kapa'a
# Processing Record 12 of Set 3 | calama
# Processing Record 13 of Set 3 | daru
# Processing Record 14 of Set 3 | amnat charoen
# Processing Record 15 of Set 3 | egilsstadir
# Processing Record 16 of Set 3 | tsiombe
# Processing Record 17 of Set 3 | tirumullaivasal
# Processing Record 18 of Set 3 | shalqar
# Processing Record 19 of Set 3 | madan
# Processing Record 20 of Set 3 | igarka
# Processing Record 21 of Set 3 | san andros
# City not found. Skipping...
# Processing Record 22 of Set 3 | nizhnesortymskiy
# Processing Record 23 of Set 3 | trincomalee
# Processing Record 24 of Set 3 | bonthe
# Processing Record 25 of Set 3 | majene
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | iskateley
# Processing Record 29 of Set 3 | mstsislaw
# Processing Record 30 of Set 3 | bereznik
# Processing Record 31 of Set 3 | constantia
# Processing Record 32 of Set 3 | wailua homesteads
# Processing Record 33 of Set 3 | saipan
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | san pedro pochutla
# Processing Record 37 of Set 3 | mataram
# Processing Record 38 of Set 3 | ismayilli
# Processing Record 39 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 3 | maumere
# Processing Record 41 of Set 3 | eyl
# Processing Record 42 of Set 3 | ola
# Processing Record 43 of Set 3 | khandyga
# Processing Record 44 of Set 3 | kapuskasing
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | ust-nera
# Processing Record 47 of Set 3 | rockland
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | la'ie
# Processing Record 0 of Set 4 | victoria point
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | cabo san lucas
# Processing Record 3 of Set 4 | aykhal
# Processing Record 4 of Set 4 | zeya
# Processing Record 5 of Set 4 | keflavik
# Processing Record 6 of Set 4 | villamontes
# Processing Record 7 of Set 4 | taltal
# Processing Record 8 of Set 4 | pedregal
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | kailua-kona
# Processing Record 11 of Set 4 | punta arenas
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 14 of Set 4 | atafu village
# Processing Record 15 of Set 4 | hobyo
# Processing Record 16 of Set 4 | ribeira brava
# Processing Record 17 of Set 4 | kalianget
# Processing Record 18 of Set 4 | fale old settlement
# Processing Record 19 of Set 4 | margaret river
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | suntar
# Processing Record 22 of Set 4 | nakhon sawan
# Processing Record 23 of Set 4 | hilo
# Processing Record 24 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 4 | hamilton
# Processing Record 26 of Set 4 | signal mountain
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | ternate
# Processing Record 29 of Set 4 | olyokminsk
# Processing Record 30 of Set 4 | tagta
# Processing Record 31 of Set 4 | grand falls-windsor
# Processing Record 32 of Set 4 | quellon
# Processing Record 33 of Set 4 | hami
# Processing Record 34 of Set 4 | robore
# Processing Record 35 of Set 4 | port augusta
# Processing Record 36 of Set 4 | puerto deseado
# Processing Record 37 of Set 4 | puerto baquerizo moreno
# Processing Record 38 of Set 4 | freetown
# Processing Record 39 of Set 4 | sao tome
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | coahuayana de hidalgo
# Processing Record 42 of Set 4 | hotan
# Processing Record 43 of Set 4 | hawaiian paradise park
# Processing Record 44 of Set 4 | namdrik
# Processing Record 45 of Set 4 | tchintabaraden
# Processing Record 46 of Set 4 | pangoa
# Processing Record 47 of Set 4 | qaqortoq
# Processing Record 48 of Set 4 | ray
# Processing Record 49 of Set 4 | batticaloa
# Processing Record 0 of Set 5 | piritiba
# Processing Record 1 of Set 5 | onguday
# Processing Record 2 of Set 5 | kununurra
# Processing Record 3 of Set 5 | dul'durga
# Processing Record 4 of Set 5 | usogorsk
# Processing Record 5 of Set 5 | ishtixon shahri
# City not found. Skipping...
# Processing Record 6 of Set 5 | laojunmiao
# Processing Record 7 of Set 5 | nenjiang
# Processing Record 8 of Set 5 | klyuchi
# Processing Record 9 of Set 5 | tura
# Processing Record 10 of Set 5 | pangkalanbuun
# Processing Record 11 of Set 5 | utrik
# Processing Record 12 of Set 5 | sola
# Processing Record 13 of Set 5 | san antonio de pale
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | buchanan
# Processing Record 16 of Set 5 | zheleznogorsk
# Processing Record 17 of Set 5 | weno
# Processing Record 18 of Set 5 | evanston
# Processing Record 19 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 20 of Set 5 | puerto madero
# Processing Record 21 of Set 5 | boromo
# Processing Record 22 of Set 5 | lihue
# Processing Record 23 of Set 5 | karatau
# Processing Record 24 of Set 5 | high rock
# Processing Record 25 of Set 5 | kodinar
# Processing Record 26 of Set 5 | pitanga
# Processing Record 27 of Set 5 | nepanagar
# Processing Record 28 of Set 5 | thayetmyo
# Processing Record 29 of Set 5 | berbera
# Processing Record 30 of Set 5 | sandnessjoen
# Processing Record 31 of Set 5 | kutum
# Processing Record 32 of Set 5 | atbasar
# Processing Record 33 of Set 5 | katabu
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | bafq
# Processing Record 36 of Set 5 | nova sintra
# Processing Record 37 of Set 5 | ebon
# Processing Record 38 of Set 5 | la passe
# Processing Record 39 of Set 5 | vadso
# Processing Record 40 of Set 5 | conde
# Processing Record 41 of Set 5 | hadibu
# Processing Record 42 of Set 5 | buta
# Processing Record 43 of Set 5 | labytnangi
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | porto novo
# Processing Record 46 of Set 5 | ballina
# Processing Record 47 of Set 5 | howard springs
# Processing Record 48 of Set 5 | kayangel
# Processing Record 49 of Set 5 | ilebo
# Processing Record 0 of Set 6 | weiser
# Processing Record 1 of Set 6 | fort-shevchenko
# Processing Record 2 of Set 6 | xinguara
# City not found. Skipping...
# Processing Record 3 of Set 6 | nabire
# Processing Record 4 of Set 6 | ghanzi
# Processing Record 5 of Set 6 | ipoh
# Processing Record 6 of Set 6 | nyurba
# Processing Record 7 of Set 6 | san jose del guaviare
# Processing Record 8 of Set 6 | trancas
# Processing Record 9 of Set 6 | saint-philippe
# Processing Record 10 of Set 6 | inhambane
# Processing Record 11 of Set 6 | gushu
# Processing Record 12 of Set 6 | dryden
# Processing Record 13 of Set 6 | mata-utu
# Processing Record 14 of Set 6 | tofol
# Processing Record 15 of Set 6 | kingston
# Processing Record 16 of Set 6 | pasargad
# City not found. Skipping...
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | puerto lopez
# Processing Record 19 of Set 6 | howrah
# Processing Record 20 of Set 6 | port mathurin
# Processing Record 21 of Set 6 | launceston
# Processing Record 22 of Set 6 | luganville
# Processing Record 23 of Set 6 | chui
# Processing Record 24 of Set 6 | south valley
# Processing Record 25 of Set 6 | smirnykh
# Processing Record 26 of Set 6 | baneh
# Processing Record 27 of Set 6 | uturoa
# Processing Record 28 of Set 6 | krasnogorskoye
# Processing Record 29 of Set 6 | manokwari
# Processing Record 30 of Set 6 | anicuns
# Processing Record 31 of Set 6 | galveston
# Processing Record 32 of Set 6 | kanniyakumari
# Processing Record 33 of Set 6 | uvira
# Processing Record 34 of Set 6 | mhamid
# Processing Record 35 of Set 6 | pangai
# Processing Record 36 of Set 6 | zvornik
# Processing Record 37 of Set 6 | diboll
# Processing Record 38 of Set 6 | kudymkar
# Processing Record 39 of Set 6 | prince rupert
# Processing Record 40 of Set 6 | santana
# Processing Record 41 of Set 6 | barranca
# Processing Record 42 of Set 6 | cheongsong gun
# Processing Record 43 of Set 6 | chipiona
# Processing Record 44 of Set 6 | hirara
# Processing Record 45 of Set 6 | kuhdasht
# Processing Record 46 of Set 6 | bontang
# Processing Record 47 of Set 6 | sosnovo-ozerskoye
# Processing Record 48 of Set 6 | gwio kura
# Processing Record 49 of Set 6 | ketchikan
# Processing Record 0 of Set 7 | tvoroyri
# Processing Record 1 of Set 7 | zima
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | puerto aventuras
# City not found. Skipping...
# Processing Record 4 of Set 7 | bel ombre
# Processing Record 5 of Set 7 | monrovia
# Processing Record 6 of Set 7 | afaahiti
# Processing Record 7 of Set 7 | berdigestyakh
# Processing Record 8 of Set 7 | hluti
# Processing Record 9 of Set 7 | island harbour
# Processing Record 10 of Set 7 | carutapera
# Processing Record 11 of Set 7 | cockburn town
# Processing Record 12 of Set 7 | skowhegan
# Processing Record 13 of Set 7 | makary
# Processing Record 14 of Set 7 | quesnel
# Processing Record 15 of Set 7 | hammerfest
# Processing Record 16 of Set 7 | ba
# City not found. Skipping...
# Processing Record 17 of Set 7 | gilgit
# Processing Record 18 of Set 7 | kone
# Processing Record 19 of Set 7 | dawukou
# Processing Record 20 of Set 7 | enewetak
# Processing Record 21 of Set 7 | greymouth
# Processing Record 22 of Set 7 | pacocha
# Processing Record 23 of Set 7 | sorong
# Processing Record 24 of Set 7 | al ghayzah
# Processing Record 25 of Set 7 | baoqing
# Processing Record 26 of Set 7 | the pas
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | kirensk
# Processing Record 29 of Set 7 | macapa
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | college
# Processing Record 32 of Set 7 | shihezi
# Processing Record 33 of Set 7 | bumba
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | kattivakkam
# Processing Record 36 of Set 7 | san jose ixtapa (barrio viejo)
# City not found. Skipping...
# Processing Record 37 of Set 7 | celestun
# Processing Record 38 of Set 7 | bargaal
# Processing Record 39 of Set 7 | pali
# Processing Record 40 of Set 7 | lalganj
# Processing Record 41 of Set 7 | karymskoye
# Processing Record 42 of Set 7 | rurrenabaque
# Processing Record 43 of Set 7 | sao jose da coroa grande
# Processing Record 44 of Set 7 | honjo
# Processing Record 45 of Set 7 | bodden town
# Processing Record 46 of Set 7 | adrar
# Processing Record 47 of Set 7 | pontes e lacerda
# Processing Record 48 of Set 7 | tehran
# Processing Record 49 of Set 7 | san jeronimo de juarez
# Processing Record 0 of Set 8 | antonio enes
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | al kharijah
# Processing Record 3 of Set 8 | vilani
# Processing Record 4 of Set 8 | new norfolk
# Processing Record 5 of Set 8 | carauari
# Processing Record 6 of Set 8 | nukunonu
# City not found. Skipping...
# Processing Record 7 of Set 8 | alofi
# Processing Record 8 of Set 8 | hopewell
# Processing Record 9 of Set 8 | lashio
# Processing Record 10 of Set 8 | bougouni
# Processing Record 11 of Set 8 | mugia
# Processing Record 12 of Set 8 | damghan
# Processing Record 13 of Set 8 | ceerigaabo
# Processing Record 14 of Set 8 | oualidia
# City not found. Skipping...
# Processing Record 15 of Set 8 | pacific grove
# Processing Record 16 of Set 8 | colby
# Processing Record 17 of Set 8 | glens falls north
# Processing Record 18 of Set 8 | acarau
# Processing Record 19 of Set 8 | kurumkan
# Processing Record 20 of Set 8 | umluj
# Processing Record 21 of Set 8 | myeik
# Processing Record 22 of Set 8 | ariquemes
# Processing Record 23 of Set 8 | qamdo
# Processing Record 24 of Set 8 | pombas
# Processing Record 25 of Set 8 | hithadhoo
# Processing Record 26 of Set 8 | canutama
# Processing Record 27 of Set 8 | jining
# Processing Record 28 of Set 8 | taroa
# Processing Record 29 of Set 8 | labuan
# Processing Record 30 of Set 8 | tres arroyos
# Processing Record 31 of Set 8 | mochudi
# Processing Record 32 of Set 8 | kawthoung
# City not found. Skipping...
# Processing Record 33 of Set 8 | kaohsiung
# Processing Record 34 of Set 8 | alesund
# Processing Record 35 of Set 8 | sepolno krajenskie
# Processing Record 36 of Set 8 | patamundai
# Processing Record 37 of Set 8 | balakhta
# Processing Record 38 of Set 8 | khovd
# Processing Record 39 of Set 8 | chahuite
# Processing Record 40 of Set 8 | ingeniero jacobacci
# Processing Record 41 of Set 8 | kavaratti
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | boguchany
# Processing Record 44 of Set 8 | kertih
# Processing Record 45 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 8 | nuuk
# Processing Record 47 of Set 8 | nova vicosa
# Processing Record 48 of Set 8 | vodice
# Processing Record 49 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 0 of Set 9 | rio gallegos
# Processing Record 1 of Set 9 | montepuez
# Processing Record 2 of Set 9 | mahina
# Processing Record 3 of Set 9 | saint-paul
# Processing Record 4 of Set 9 | gizo
# Processing Record 5 of Set 9 | alexandria
# Processing Record 6 of Set 9 | dunedin
# Processing Record 7 of Set 9 | garoowe
# Processing Record 8 of Set 9 | kruisfontein
# Processing Record 9 of Set 9 | ahmadpur sial
# Processing Record 10 of Set 9 | saint croix
# Processing Record 11 of Set 9 | changleng
# Processing Record 12 of Set 9 | pijijiapan
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | ust'-kulom
# Processing Record 15 of Set 9 | bryne
# Processing Record 16 of Set 9 | okhotsk
# Processing Record 17 of Set 9 | bermejo
# Processing Record 18 of Set 9 | lazaro cardenas
# Processing Record 19 of Set 9 | silistra
# Processing Record 20 of Set 9 | erdenet
# Processing Record 21 of Set 9 | victorica
# Processing Record 22 of Set 9 | richlands
# Processing Record 23 of Set 9 | pakxan
# Processing Record 24 of Set 9 | kondopoga
# Processing Record 25 of Set 9 | n'zeto
# Processing Record 26 of Set 9 | bikenibeu village
# Processing Record 27 of Set 9 | gonzaga
# Processing Record 28 of Set 9 | kapenguria
# Processing Record 29 of Set 9 | angaur state
# Processing Record 30 of Set 9 | tieli
# Processing Record 31 of Set 9 | chela
# Processing Record 32 of Set 9 | haiku-pauwela
# Processing Record 33 of Set 9 | pokrovsk
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | butte
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | el granada
# Processing Record 38 of Set 9 | talcahuano
# Processing Record 39 of Set 9 | sala
# Processing Record 40 of Set 9 | ust-tsilma
# Processing Record 41 of Set 9 | makurazaki
# Processing Record 42 of Set 9 | severodvinsk
# Processing Record 43 of Set 9 | polyarnyy
# Processing Record 44 of Set 9 | nuriootpa
# Processing Record 45 of Set 9 | fortuna
# Processing Record 46 of Set 9 | horta
# Processing Record 47 of Set 9 | vilyuchinsk
# Processing Record 48 of Set 9 | rumphi
# Processing Record 49 of Set 9 | piti village
# Processing Record 0 of Set 10 | ringas
# Processing Record 1 of Set 10 | mbekenyera
# Processing Record 2 of Set 10 | tanki leendert
# City not found. Skipping...
# Processing Record 3 of Set 10 | volkhov
# Processing Record 4 of Set 10 | olonets
# Processing Record 5 of Set 10 | colonia
# Processing Record 6 of Set 10 | keetmanshoop
# Processing Record 7 of Set 10 | le vauclin
# Processing Record 8 of Set 10 | pokaran
# Processing Record 9 of Set 10 | huntsville
# Processing Record 10 of Set 10 | yako
# Processing Record 11 of Set 10 | machina
# Processing Record 12 of Set 10 | raja
# Processing Record 13 of Set 10 | kristiansund
# Processing Record 14 of Set 10 | uzgen
# Processing Record 15 of Set 10 | svetlyy
# Processing Record 16 of Set 10 | susuman
# Processing Record 17 of Set 10 | benghazi
# Processing Record 18 of Set 10 | chake chake
# Processing Record 19 of Set 10 | al mishkhab
# Processing Record 20 of Set 10 | saudarkrokur
# Processing Record 21 of Set 10 | qapqal
# City not found. Skipping...
# Processing Record 22 of Set 10 | arvayheer
# Processing Record 23 of Set 10 | las amilpas
# Processing Record 24 of Set 10 | luwingu
# Processing Record 25 of Set 10 | athens
# Processing Record 26 of Set 10 | narrabri
# Processing Record 27 of Set 10 | dudinka
# Processing Record 28 of Set 10 | sao joao da barra
# Processing Record 29 of Set 10 | araguaina
# Processing Record 30 of Set 10 | ust'-uda
# Processing Record 31 of Set 10 | sisimiut
# Processing Record 32 of Set 10 | sandy hill
# Processing Record 33 of Set 10 | sufalat sama'il
# Processing Record 34 of Set 10 | portland
# Processing Record 35 of Set 10 | tasqala
# Processing Record 36 of Set 10 | likhoslavl'
# Processing Record 37 of Set 10 | illizi
# Processing Record 38 of Set 10 | diego de almagro
# Processing Record 39 of Set 10 | bei'an
# Processing Record 40 of Set 10 | makinsk
# Processing Record 41 of Set 10 | madimba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# Convert Raw Data to Dataframe
#
#     Export the data into .csv.
#     Display the dataframe.

# %%
# Load the dataframe
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          472
# Lat           472
# Lng           472
# Max Temp      472
# Humidity      472
# Cloudiness    472
# Wind Speed    472
# Country       472
# Date          472
# dtype: int64

# %%
# Display df with header
city_data_pd.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  la huacana  18.9667 -101.8167     88.47        30           0        5.79
# 1   grytviken -54.2811  -36.5092     46.60        74          27        5.57
# 2      kodiak  57.7900 -152.4072     24.31        80           0        5.75
# 3  mapastepec  15.4333  -92.9000     92.41        37         100        4.68
# 4   gaalkacyo   6.7697   47.4308     83.71        49          39       19.30
#
#   Country        Date
# 0      MX  1744217041
# 1      GS  1744216983
# 2      US  1744216991
# 3      MX  1744217041
# 4      SO  1744217041

# %% [markdown]
# Remove the cities where the humidity is above 100%.

# %%
# Description of data
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  472.000000  472.000000  472.000000  472.000000  472.000000  472.000000
# mean    17.965753   17.785876   62.414047   67.896186   60.656780    8.771949
# std     33.135067   92.054939   23.473856   22.791118   37.929827    5.927831
# min    -54.800000 -176.559700  -17.680000    6.000000    0.000000    0.000000
# 25%     -8.552400  -65.550375   46.095000   54.750000   20.000000    4.022500
# 50%     19.685150   25.914000   68.395000   74.000000   75.000000    7.570000
# 75%     46.280850   97.523150   80.745000   85.000000   98.000000   12.592500
# max     78.218600  178.441500  105.690000  100.000000  100.000000   31.970000
#
#                Date
# count  4.720000e+02
# mean   1.744217e+09
# std    5.293330e+01
# min    1.744217e+09
# 25%    1.744217e+09
# 50%    1.744217e+09
# 75%    1.744217e+09
# max    1.744217e+09

# %%
# Get the indices of cities that have humidity over 100%
dirty_city = city_data_pd[(city_data_pd["Humidity"]>100)].index
dirty_city
# Out:
# Index([], dtype='int64')

# %%
# Make a new DataFrame and have all of the humidity outliers dropped.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_data = city_data_pd.drop(dirty_city, inplace = False)
clean_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  la huacana  18.9667 -101.8167     88.47        30           0        5.79
# 1   grytviken -54.2811  -36.5092     46.60        74          27        5.57
# 2      kodiak  57.7900 -152.4072     24.31        80           0        5.75
# 3  mapastepec  15.4333  -92.9000     92.41        37         100        4.68
# 4   gaalkacyo   6.7697   47.4308     83.71        49          39       19.30
#
#   Country        Date
# 0      MX  1744217041
# 1      GS  1744216983
# 2      US  1744216991
# 3      MX  1744217041
# 4      SO  1744217041

# %%
# Preparing the columns for plotting
lats = clean_data["Lat"]
max_temps = clean_data["Max Temp"]
humidity = clean_data["Humidity"]
cloudiness = clean_data["Cloudiness"]
wind_speed = clean_data["Wind Speed"]

# Export the City_Data into a csv
clean_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# Plotting the Data
#
#     Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#     Save the plotted figures as .pngs.

# %% [markdown]
# Latitude v Temperature Plot

# %%
# Create design for the plot
plt.scatter(lats, max_temps, edgecolor="red", linewidth=0.5, marker="o", alpha=1.0, label="Cities")

# Declare the x and y axes
plt.title(f"Latitude v Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)

# Save the plot and display
plt.savefig("output_data/LatvTemp.png")
plt.show()

# %% [raw]
# This graph shows that maximum temperature increases as the latitude approaches 0.

# %% [markdown]
# Latitude v Humidity Plot

# %%
# Create design for the plot
plt.scatter(lats, humidity, edgecolor="red", linewidth=0.5, marker="o", alpha=1.0, label="Cities")

# Declare the x and y axes
plt.title(f"Latitude v Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the plot and display
plt.savefig("output_data/LatvHumidity.png")
plt.show()

# %% [raw]
# The plot shows that humidity is less predictable due to latitude than temperature is.

# %% [markdown]
# Latitude v Cloudiness Plot

# %%
# Create design for the plot
plt.scatter(lats, cloudiness, edgecolor="red", linewidth=0.5, marker="o", alpha=1.0, label="Cities")

# Declare the x and y axes
plt.title(f"Latitude v Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the plot and display
plt.savefig("output_data/LatvCloudiness.png")
plt.show()

# %% [raw]
# Cloudiness is not necessarily related to latitude.

# %% [markdown]
# Latitude v Wind Speed Plot

# %%
# Create design for the plot
plt.scatter(lats, wind_speed, edgecolor="red", linewidth=0.5, marker="o", alpha=1.0, label="Cities")

# Declare the x and y axes
plt.title(f"Latitude v Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the plot and display
plt.savefig("output_data/LatvWindSpeed.png")
plt.show()

# %% [raw]
# Wind speed is not relevant to latitude.

# %% [markdown]
# Linear Regression

# %%
# Create Northern Hemisphere DataFrame
northern_hemisphere = city_data_pd.loc[city_data_pd["Lat"] >= 0]

# Display
northern_hemisphere.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  la huacana  18.9667 -101.8167     88.47        30           0        5.79
# 2      kodiak  57.7900 -152.4072     24.31        80           0        5.75
# 3  mapastepec  15.4333  -92.9000     92.41        37         100        4.68
# 4   gaalkacyo   6.7697   47.4308     83.71        49          39       19.30
# 5      anadyr  64.7500  177.4833     -5.30        77           0        8.95
#
#   Country        Date
# 0      MX  1744217041
# 2      US  1744216991
# 3      MX  1744217041
# 4      SO  1744217041
# 5      RU  1744217005

# %%
# Create Southern hemisphere DataFrame
southern_hemisphere = city_data_pd.loc[city_data_pd["Lat"] < 0]

# Display
southern_hemisphere.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1           grytviken -54.2811  -36.5092     46.60        74          27
# 6           adamstown -25.0660 -130.1015     74.23        68          90
# 10           castelli -25.9468  -60.6195     79.70        38           0
# 14  port-aux-francais -49.3500   70.2167     41.72        81          77
# 17          inverloch -38.6333  145.7167     58.48        81         100
#
#     Wind Speed Country        Date
# 1         5.57      GS  1744216983
# 6         9.57      PN  1744216980
# 10        5.61      AR  1744217042
# 14       26.44      TF  1744216986
# 17        7.11      AU  1744217042

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# Northern Hemisphere - Latitude v Temperature Linear Regression

# %%
# Call a function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call a function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Latitude v Temperature Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Temperature (F)")

# Save the figure
plt.savefig("output_data/Northern Hemisphere - Latitude v Temperature Linear Regression.png")
# Out:
# The r-squared is : -0.88

# %% [markdown]
# Southern Hemisphere - Latitude v Temperature Linear Regression

# %%
# Call a function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])

# Call a function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Latitude v Temperature Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Temperature (F)")

# Save the figure
plt.savefig("output_data/Southern Hemisphere - Latitude v Temperature Linear Regression.png")
# Out:
# The r-squared is : 0.82

# %% [markdown]
# Northern Hemisphere - Latitude v Humidity Linear Regression

# %%
# Call a function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call a function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Latitude v Humidity Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Northern Hemisphere - Latitude v Humidity Linear Regression.png")
# Out:
# The r-squared is : 0.26

# %% [markdown]
# Southern Hemisphere Latitude v Humidity Linear Regression

# %%
# Call a function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call a function #2
annotate(equation, -40, 50)

# Set a title
plt.title("Southern Hemisphere - Latitude v Humidity Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Southern Hemisphere - Latitude v Humidity Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# Northern Hemisphere - Latitude v Cloudiness Linear Regression

# %%
# Call a function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call a function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Latitude v Cloudiness Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Northern Hemisphere - Latitude v Cloudiness Linear Regression.png")
# Out:
# The r-squared is : 0.23

# %% [markdown]
# Southern Hemisphere - Latitude v Cloudiness Linear Regression

# %%
# Call a function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call a function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Latitude v Cloudiness Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Southern Hemisphere - Latitude v Cloudiness Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# Northern Hemisphere - Latitude v Wind Speed Linear Regression

# %%
# Call a function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call a function #2
annotate(equation, 40, 25)

# Set a title
plt.title("Northern Hemisphere - Latitude v Wind Speed Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("output_data/Northern Hemisphere - Latitude v Wind Speed Linear Regression.png")
# Out:
# The r-squared is : 0.09

# %% [markdown]
# Southern Hemisphere - Latitude v Wind Speed Linear Regression

# %%
# Call a function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call a function #2
annotate(equation, -30, 15)

# Set a title
plt.title("Southern Hemisphere - Latitude v Wind Speed Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("output_data/Southern Hemisphere - Latitude v Wind Speed Linear Regression.png")
# Out:
# The r-squared is : -0.23
